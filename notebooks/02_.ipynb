# %%
import sys, os
sys.path.append(os.path.abspath(".."))

# %%
#%% [markdown]
# ## 1. Random súlyok táblázatos megjelenítése

#%%
import numpy as np
import pandas as pd
import random


# Betöltjük az elmentett súlyokat
weights_data = np.load("../data/weights/simplemlp_weights.npz")

# Összegyűjtünk néhány véletlen elemet
rows = []
for key in weights_data.files:
    arr = weights_data[key]
    flat = arr.flatten()
    for _ in range(2):
        idx = random.randrange(flat.size)
        rows.append({
            "param": key,
            "index": idx,
            "value": float(flat[idx])
        })

# DataFrame és megjelenítés
df = pd.DataFrame(rows).sample(10).reset_index(drop=True)
df["value"] = df["value"].round(4)
df
# Out:
#   param  index   value
# 0    W1   7110 -0.0972
# 1    W2    282  0.1753
# 2    W1    849 -0.1518
# 3    b2      2  0.0146
# 4    W0  87615 -0.0496
# 5    b0     34 -0.0011
# 6    b0     78 -0.0029
# 7    b1      8 -0.0007
# 8    W2    354  0.2385
# 9    b1     52 -0.0000

# %%
# ## 2. Vizuális modell-teszt 5 véletlen mintával

#%%
import numpy as np
import matplotlib.pyplot as plt
import random
import sys, os


#sys.path.append(os.path.abspath("../../../"))


# Győződjünk meg róla, hogy a model.py elérhető
#sys.path.insert(0, os.getcwd())
from simplemlp.model import SimpleMLP

# Dataset betöltése
data = np.load("../data/processed/dataset_preProcessed.npz")
images = data["images"]
labels = data["labels"]
X = images.reshape(len(images), -1) / 255.0

# Emberi olvasható osztálynevek
class_names = [
    "Jól futható erdő", "Leküzdhető növényzet", "Lassan futható erdő",
    "Nehezen futható erdő", "Nyílt terület (világos)", "Nyílt terület (erős)",
    "Durva nyílt terület", "Sekély vízfelület", "Áthatolhatatlan víz",
    "Fekete (út/szikla)"
]

# Modell inicializálása és súlyok betöltése
model = SimpleMLP()
model.load_weights("simplemlp_weights.npz")

# 5 véletlen minta kirajzolása predikcióval
indices = random.sample(range(len(images)), 5)
plt.figure(figsize=(12, 4))
for i, idx in enumerate(indices):
    plt.subplot(1, 5, i+1)
    plt.imshow(images[idx])
    pred = model.predict(X[idx:idx+1])[0]
    plt.title(class_names[pred], fontsize=9)
    plt.axis("off")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[45], line 15
#       7 import sys, os
#      10 #sys.path.append(os.path.abspath("../../../"))
#      11
#      12
#      13 # Győződjünk meg róla, hogy a model.py elérhető
#      14 #sys.path.insert(0, os.getcwd())
# ---> 15 from simplemlp.model import SimpleMLP
#      17 # Dataset betöltése
#      18 data = np.load("../data/processed/dataset_preProcessed.npz")
#
# File p:\_Projects\neural_networks\NeuralNetwork_basics\simplemlp\model.py:3
#       1 # simplemlp/model.py
#       2 #from simplemlp.layers import Dense, ReLU, Softmax, cross_entropy, cross_entropy_grad
# ----> 3 from layers import Dense, ReLU, Softmax, cross_entropy, cross_entropy_grad
#       4 import numpy as np
#       6 class SimpleMLP:
#
# ModuleNotFoundError: No module named 'layers'
